# %%
from functools import partial
import numpy as np
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import RMSprop
from torch.utils.data import random_split, DataLoader, TensorDataset
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %%
features,target = make_classification(n_classes=2,
                                      n_samples=1000,
                                      n_features=10)
features_train,features_test,target_train,target_test = train_test_split(features,target,test_size=0.1,random_state=1)

torch.manual_seed(0)
np.random.seed(0)

x_train = torch.from_numpy(features_train).float()
y_train = torch.from_numpy(target_train).float().view(-1,1)
x_test = torch.from_numpy(features_test).float()
y_test = torch.from_numpy(target_test).float().view(-1,1)

# %%
class SimpleNeuralNet(nn.Module):
  def __init__(self,layer_size_1=10,layer_size_2=10):
    super(SimpleNeuralNet,self).__init__()
    self.sequential = torch.nn.Sequential(
        torch.nn.Linear(10,layer_size_1),
        torch.nn.ReLU(),
        torch.nn.Linear(layer_size_1,layer_size_2),
        torch.nn.ReLU(),
        torch.nn.Linear(layer_size_2,1),
        torch.nn.Sigmoid()
    )
  def forward(self,x):
    x = self.sequential(x)
    return x

# %%
config = {
    "layer_size_1" : tune.sample_from(lambda _: 2 ** np.random.randint(2, 9)),
    "layer_size_2" : tune.sample_from(lambda _: 2 ** np.random.randint(2, 9)),
    "lr" : tune.loguniform(1e-4, 1e-1),
}

scheduler = ASHAScheduler(
    metric="loss",
    mode="min",
    max_t=1000,
    grace_period=1,
    reduction_factor=2
)

reporter = CLIReporter(
    parameter_columns=["layer_size_1", "layer_size_2", "lr"],
    metric_columns=["loss"]
)

# %%
def train_model(config,epochs=3):
  network = SimpleNeuralNet(config['layer_size_1'],config['layer_size_2'])

  criterion = nn.BCELoss()
  optimizer = optim.Adam(network.parameters(),lr=config['lr'])

  train_data = TensorDataset(x_train,y_train)
  train_loader = DataLoader(train_data,batch_size=100,shuffle=True)

  network = torch.compile(network)

  for epoch in range(epochs):
    for batch_idx,(data,target) in enumerate(train_loader):
      optimizer.zero_grad()
      outputs = network(data)
      loss = criterion(outputs,target)
      loss.backward()
      optimizer.step()
      tune.report({'loss': loss.item()})

# %%
result = tune.run(
    train_model,
    resources_per_trial={"cpu": 2},
    config=config,
    num_samples=1,
    scheduler=scheduler,
    progress_reporter=reporter
)

best_trial = result.get_best_trial("loss", "min", "last")
print("Best trial config:" .format(best_trial.config))
print("Best trial final validation loss:".format (best_trial.last_result['loss']))

best_trained_model = SimpleNeuralNet(best_trial.config['layer_size_1'],best_trial.config['layer_size_2'])
# Out:
# 2025-11-12 04:45:20,724	WARNING callback.py:143 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# 2025-11-12 04:45:20,727	WARNING tune.py:902 -- AIR_VERBOSITY is set, ignoring passed-in ProgressReporter for now.
# +--------------------------------------------------------------------+
# | Configuration for experiment     train_model_2025-11-12_04-45-20   |
# +--------------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator             |
# | Scheduler                        AsyncHyperBandScheduler           |
# | Number of trials                 1                                 |
# +--------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/train_model_2025-11-12_04-45-20
#
# Trial status: 1 PENDING
# Current time: 2025-11-12 04:45:20. Total running time: 0s
# Logical resource usage: 0/2 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                status             lr |
# +-------------------------------------------------+
# | train_model_64db5_00000   PENDING    0.00205476 |
# +-------------------------------------------------+
#
# Trial train_model_64db5_00000 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 config             |
# +--------------------------------------------------+
# | layer_size_1                                 256 |
# | layer_size_2                                   4 |
# | lr                                       0.00205 |
# +--------------------------------------------------+
# (train_model pid=8368) W1112 04:45:44.382000 8368 torch/utils/cpp_extension.py:118] [0/0] No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Trial status: 1 RUNNING
# Current time: 2025-11-12 04:45:50. Total running time: 30s
# Logical resource usage: 2.0/2 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                status             lr |
# +-------------------------------------------------+
# | train_model_64db5_00000   RUNNING    0.00205476 |
# +-------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 1 at 2025-11-12 04:45:51. Total running time: 30s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         17.8305 |
# | time_total_s                             17.8305 |
# | training_iteration                             1 |
# | loss                                     0.68308 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 2 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                          0.0051 |
# | time_total_s                             17.8356 |
# | training_iteration                             2 |
# | loss                                     0.69444 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 3 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00452 |
# | time_total_s                             17.8401 |
# | training_iteration                             3 |
# | loss                                      0.6898 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 4 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00435 |
# | time_total_s                             17.8444 |
# | training_iteration                             4 |
# | loss                                     0.65339 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 5 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00415 |
# | time_total_s                             17.8486 |
# | training_iteration                             5 |
# | loss                                      0.6663 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 6 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00411 |
# | time_total_s                             17.8527 |
# | training_iteration                             6 |
# | loss                                     0.64511 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 7 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                          0.0043 |
# | time_total_s                              17.857 |
# | training_iteration                             7 |
# | loss                                     0.61656 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 8 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00406 |
# | time_total_s                              17.861 |
# | training_iteration                             8 |
# | loss                                     0.60447 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 9 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00412 |
# | time_total_s                             17.8652 |
# | training_iteration                             9 |
# | loss                                     0.60129 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 10 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00471 |
# | time_total_s                             17.8699 |
# | training_iteration                            10 |
# | loss                                     0.60599 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 11 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00405 |
# | time_total_s                             17.8739 |
# | training_iteration                            11 |
# | loss                                     0.59165 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 12 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00413 |
# | time_total_s                             17.8781 |
# | training_iteration                            12 |
# | loss                                     0.58019 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 13 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                           0.004 |
# | time_total_s                             17.8821 |
# | training_iteration                            13 |
# | loss                                     0.59698 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 14 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00503 |
# | time_total_s                             17.8871 |
# | training_iteration                            14 |
# | loss                                     0.55904 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 15 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00415 |
# | time_total_s                             17.8912 |
# | training_iteration                            15 |
# | loss                                     0.53418 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 16 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00409 |
# | time_total_s                             17.8953 |
# | training_iteration                            16 |
# | loss                                     0.55618 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 17 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00394 |
# | time_total_s                             17.8993 |
# | training_iteration                            17 |
# | loss                                     0.54969 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 18 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00543 |
# | time_total_s                             17.9047 |
# | training_iteration                            18 |
# | loss                                     0.52176 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 19 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00441 |
# | time_total_s                             17.9091 |
# | training_iteration                            19 |
# | loss                                     0.52841 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 20 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00398 |
# | time_total_s                             17.9131 |
# | training_iteration                            20 |
# | loss                                     0.52558 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 21 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00389 |
# | time_total_s                              17.917 |
# | training_iteration                            21 |
# | loss                                     0.53556 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 22 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                          0.0039 |
# | time_total_s                             17.9209 |
# | training_iteration                            22 |
# | loss                                     0.51976 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 23 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00394 |
# | time_total_s                             17.9248 |
# | training_iteration                            23 |
# | loss                                     0.49119 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 24 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                          0.0042 |
# | time_total_s                              17.929 |
# | training_iteration                            24 |
# | loss                                     0.52586 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 25 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00435 |
# | time_total_s                             17.9334 |
# | training_iteration                            25 |
# | loss                                      0.4692 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 finished iteration 26 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                          0.0042 |
# | time_total_s                             17.9376 |
# | training_iteration                            26 |
# | loss                                     0.47521 |
# +--------------------------------------------------+
# 2025-11-12 04:45:51,958	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/train_model_2025-11-12_04-45-20' in 0.0063s.
# Trial train_model_64db5_00000 finished iteration 27 at 2025-11-12 04:45:51. Total running time: 31s
# +--------------------------------------------------+
# | Trial train_model_64db5_00000 result             |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                         0.00944 |
# | time_total_s                              17.947 |
# | training_iteration                            27 |
# | loss                                     0.42595 |
# +--------------------------------------------------+
#
# Trial train_model_64db5_00000 completed after 27 iterations at 2025-11-12 04:45:51. Total running time: 31s
#
# Trial status: 1 TERMINATED
# Current time: 2025-11-12 04:45:51. Total running time: 31s
# Logical resource usage: 2.0/2 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------+
# | Trial name                status               lr     iter     total time (s)       loss |
# +------------------------------------------------------------------------------------------+
# | train_model_64db5_00000   TERMINATED   0.00205476       27             17.947   0.425947 |
# +------------------------------------------------------------------------------------------+
#
# Best trial config:
# Best trial final validation loss:
